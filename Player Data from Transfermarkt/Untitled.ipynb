# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv('players.csv')
df1
# Out:
#        player_id first_name          last_name                        name  \
# 0             10   Miroslav              Klose              Miroslav Klose
# 1             26      Roman       Weidenfeller          Roman Weidenfeller
# 2             65    Dimitar           Berbatov            Dimitar Berbatov
# 3             77        NaN              Lúcio                       Lúcio
# 4             80        Tom             Starke                  Tom Starke
# ...          ...        ...                ...                         ...
# 30352    1163778     Kahveh       Zahiroleslam         Kahveh Zahiroleslam
# 30353    1166093   Georgios  Konstantakopoulos  Georgios Konstantakopoulos
# 30354    1173042      Djibi               Seck                  Djibi Seck
# 30355    1176345  Mahamadou             Nagida            Mahamadou Nagida
# 30356    1186012     Bakary            Haidara              Bakary Haidara
#
#        last_season  current_club_id                 player_code  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30357 entries, 0 to 30356
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             30357 non-null  int64
#  1   first_name                            28379 non-null  object
#  2   last_name                             30357 non-null  object
#  3   name                                  30357 non-null  object
#  4   last_season                           30357 non-null  int64
#  5   current_club_id                       30357 non-null  int64
#  6   player_code                           30357 non-null  object
#  7   country_of_birth                      27678 non-null  object
#  8   city_of_birth                         28172 non-null  object
#  9   country_of_citizenship                29808 non-null  object
#  10  date_of_birth                         30311 non-null  object
# ...

# %%
df2 = pd.read_csv('player_valuations.csv')
df2
# Out:
#         player_id        date  market_value_in_eur  current_club_id  \
# 0          405973  2000-01-20               150000             3057
# 1          342216  2001-07-20               100000             1241
# 2            3132  2003-12-09               400000              126
# 3            6893  2003-12-15               900000              984
# 4              10  2004-10-04              7000000              398
# ...           ...         ...                  ...              ...
# 464648     777005  2024-01-08               800000              167
# 464649     816974  2024-01-08              2000000              383
# 464650     361508  2024-01-10               300000               39
# 464651     675535  2024-01-10               400000               24
# 464652     800946  2024-01-10              1000000               79
#
#        player_club_domestic_competition_id
# 0                                      BE1
# 1                                      SC1
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464653 entries, 0 to 464652
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   player_id                            464653 non-null  int64
#  1   date                                 464653 non-null  object
#  2   market_value_in_eur                  464653 non-null  int64
#  3   current_club_id                      464653 non-null  int64
#  4   player_club_domestic_competition_id  464653 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 17.7+ MB

# %%
df3 = pd.read_csv('clubs.csv')
df3
# Out:
#      club_id             club_code                               name  \
# 0        105       sv-darmstadt-98   Sportverein Darmstadt 1898 e. V.
# 1      11127     ural-ekaterinburg              FK Ural Yekaterinburg
# 2        114     besiktas-istanbul          Beşiktaş Jimnastik Kulübü
# 3         12                as-rom         Associazione Sportiva Roma
# 4        148     tottenham-hotspur    Tottenham Hotspur Football Club
# ..       ...                   ...                                ...
# 421    68608      cf-os-belenenses                   CF Os Belenenses
# 422      724           fc-volendam             Football Club Volendam
# 423      800      atalanta-bergamo  Atalanta Bergamasca Calcio S.p.a.
# 424      979         moreirense-fc           Moreirense Futebol Clube
# 425      984  west-bromwich-albion               West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  426 non-null    int64
#  1   club_code                426 non-null    object
#  2   name                     426 non-null    object
#  3   domestic_competition_id  426 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               426 non-null    int64
#  6   average_age              388 non-null    float64
#  7   foreigners_number        426 non-null    int64
#  8   foreigners_percentage    378 non-null    float64
#  9   national_team_players    426 non-null    int64
#  10  stadium_name             426 non-null    object
#  11  stadium_seats            426 non-null    int64
#  12  net_transfer_record      426 non-null    object
#  13  coach_name               0 non-null      float64
# ...

# %%
df4 = pd.read_csv('competitions.csv')
df4
# Out:
#    competition_id                             competition_code  \
# 0             CIT                                    italy-cup
# 1            NLSC                         johan-cruijff-schaal
# 2             GRP                              kypello-elladas
# 3            POSU                supertaca-candido-de-oliveira
# 4            RUSS                            russian-super-cup
# 5             SUC                                    supercopa
# 6             USC                               uefa-super-cup
# 7             DK1                                  superligaen
# 8              EL                                europa-league
# 9             ES1                                       laliga
# 10            FR1                                      ligue-1
# 11            IT1                                      serie-a
# 12            NL1                                   eredivisie
# 13            RUP                                  russian-cup
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   competition_id        43 non-null     object
#  1   competition_code      43 non-null     object
#  2   name                  43 non-null     object
#  3   sub_type              43 non-null     object
#  4   type                  43 non-null     object
#  5   country_id            43 non-null     int64
#  6   country_name          36 non-null     object
#  7   domestic_league_code  36 non-null     object
#  8   confederation         43 non-null     object
#  9   url                   43 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 3.5+ KB
